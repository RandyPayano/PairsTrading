# %%
import requests as requests, pandas as pd

from splinter import Browser 
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
import pymongo
import requests
import requests as requests, pandas as pd
import json
from splinter import Browser 
from bs4 import BeautifulSoup
from flask import jsonify
client = pymongo.MongoClient("mongodb+srv://randypayano:maldito1@cluster0-jvv32.mongodb.net/test?retryWrites=true&w=majority")
db = client.project




pairs_list = ["GOOGL", "AMZN","NVDA","BAC","JPM"]



def nolie(list):


    def news_scrapper(ticker):
        url = (f'http://newsapi.org/v2/everything?q={ticker}&from=2020-02-18&''sortBy=popularity&''apiKey=71788d9278894c70987a0a2d0e8c6120')

        x = requests.get(url)

        dict_news = x.json()

        stock_dict = {}

        for article_number in range(len("three")):
            #title = dict_news['articles'][article_number]['title']

            stock_dict['title'] = dict_news['articles'][article_number]['title']
        return stock_dict    
    
    all_mydicts = {}
    for stock in pairs_list:
        all_mydicts[stock] = news_scrapper(stock)
        myshit = [all_mydicts]
        return myshit


    
nolie(pairs_list)
# Out:
# [{'GOOGL': {'title': 'Market Extra: Why an ‘everything rally’ has some stock-market investors fearing how it will end'}}]

# %%
ticker = 'googl'

url = (f'http://newsapi.org/v2/everything?q={ticker}&from=2020-02-18&''sortBy=popularity&''apiKey=71788d9278894c70987a0a2d0e8c6120')

x = requests.get(url)
dict_news = x.json()

# %%
dict_news
# Out:
# {'status': 'ok',
#  'totalResults': 83,
#  'articles': [{'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'India is the next internet frontier (2018)',
#    'description': "India already has over 500 million internet users, a number that's set to almost double in the next decade.",
#    'url': 'https://edition.cnn.com/interactive/2018/11/business/internet-usage-india-future/',
#    'urlToImage': 'https://edition.cnn.com/interactive/2018/11/business/internet-usage-india-future/media/images/social.jpg',
#    'publishedAt': '2020-02-22T15:04:34Z',
#    'content': "Jamna Devi got her first cellphone about a year ago. It's one of those with a tiny screen and a numbered keypad, the kind that are becoming increasingly rare in the age of Android and the iPhone. \xa0Devi's village in India's Rajasthan state is almost completely… [+16186 chars]"},
#   {'source': {'id': None, 'name': 'Marketwatch.com'},
#    'author': 'Barbara Kollmeyer',
# ...

# %%
for number_article in range(len(dict_news['articles'][0]['title'])):
    number_article = number_article -1
    print(dict_news['articles'][number_article]['title'])
# Out:
# Google updates terms of service as tech industry scrutiny heats up - MarketWatch
# India is the next internet frontier (2018)
# Need to Know: Goldman Sachs warns a ‘near-term correction’ risk for stocks grows as coronavirus complacency abounds
# The Technical Indicator: Charting a bull-trend pullback, S&P 500 digests break to record territory
# Hundreds of Oracle workers stage walkout to protest Larry Ellison’s fundraiser for Trump
# Market Extra: Why an ‘everything rally’ has some stock-market investors fearing how it will end
# Best New Ideas in Health Care: DNA tests may soon give you the optimum diet for your body — down to the variety of lettuce
# Best New Ideas in Health Care: How AI ‘therapists’ could shrink the cost of mental health
# FTC Announces Antitrust Scrutiny of Big Tech
# Google's parent company is shutting down power-generating kite subsidiary Makani: 'The road to commercialization is longer and riskier than hoped' (GOOG, GOOGL)
# ...

# %%
 dict_news['articles'][1]
# Out:
# 'Stocks look ready to take a breather and you can blame that on some fresh coronavirus worries.\r\nJapan reported two deaths from a cruise ship and South Korea told 2.5 million people to stay home following its first casualty. While investors may be tired of hea… [+4003 chars]'
